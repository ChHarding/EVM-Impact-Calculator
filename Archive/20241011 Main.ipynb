# %% [markdown]
# """
# # My first app
# Here's our first attempt at using data to create a table:
# """
#
# import streamlit as st
# import pandas as pd
# df = pd.DataFrame({
#   'first column': [1, 2, 3, 4],
#   'second column': [10, 20, 30, 40]
# })
#
# df

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.widgets import RadioButtons
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import pyvista as pv



# Calculate cumulative dollars per month
class EVM_app(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title("EVM Impacts Assessment")

        # Get screen width and height and set the window to full screen
        screen_width = self.winfo_screenwidth()
        screen_height = self.winfo_screenheight()
        self.geometry(f"{screen_width}x{screen_height}")  # Set to full screen size without true fullscreen

        # Configure the grid
        self.grid_columnconfigure(0, weight=1)
        self.grid_columnconfigure(1, weight=1)
        self.grid_columnconfigure(2, weight=1)
        self.grid_columnconfigure(3, weight=1)
        self.grid_rowconfigure(8, weight=1)

        #Header
        set_1_header = tk.Label(self, text="Baseline", font=("Helvetica", 14, "bold"))
        set_1_header.grid(row=0, column=0, columnspan=2, pady=(10, 5))

        set_2_header = tk.Label(self, text="Current", font=("Helvetica", 14, "bold"))
        set_2_header.grid(row=0, column=2, columnspan=2, pady=(10, 5))

        # Labels and input fields for baseline parameters 
        self.create_input_field("Cost:", row=1, column=0, default_value="50")
        self.create_input_field("Quantity:", row=2, column=0, default_value="100")
        self.create_input_field("Yield Factor:", row=3, column=0, default_value="0.9")
        self.create_input_field("Rate Increase:", row=4, column=0, default_value="0.03")
        self.create_input_field("Lead Time:", row=5, column=0, default_value="5")
        self.create_input_field("Duration:", row=6, column=0, default_value="5")

        # Labels and input fields for current dataset parameters - want a slider bar eventually
        self.create_input_field("Cost:", row=1, column=2, default_value="40")
        self.create_input_field("Quantity:", row=2, column=2, default_value="150")
        self.create_input_field("Yield Factor:", row=3, column=2, default_value="0.85")
        self.create_input_field("Rate Increase:", row=4, column=2, default_value="0.10")
        self.create_input_field("Lead Time:", row=5, column=2, default_value="45")
        self.create_input_field("Duration:", row=6, column=2, default_value="5")

        # Button to plot bubble chart
        plot_bubble_button = tk.Button(self, text="Plot Bubble Chart", command=self.plot_charts)
        plot_bubble_button.grid(row=7, column=0, columnspan=4, pady=10, sticky="ew")

        # Create frames for line chart and bubble chart
        self.left_frame = tk.Frame(self)
        self.left_frame.grid(row=8, column=0, columnspan=2, sticky="nsew")  # Left frame for future use

        self.right_frame = tk.Frame(self)
        self.right_frame.grid(row=8, column=2,  columnspan=2, sticky="nsew")  # Right frame for bubble chart

    def plot_charts(self):

        # Clear the existing charts before plotting new ones
        self.clear_frame(self.left_frame)
        self.clear_frame(self.right_frame)
        
        # Get user input values
        cost_1 = float(self.input_Cost_Set_1.get())
        qty_1 = int(self.input_Quantity_Set_1.get())
        yield_factor_1 = float(self.input_Yield_Factor_Set_1.get())
        rate_increase_1 = float(self.input_Rate_Increase_Set_1.get())
        leadtime_1 = int(self.input_Lead_Time_Set_1.get())
        duration_1 = int(self.input_Duration_Set_1.get())

        cost_2 = float(self.input_Cost_Set_2.get())
        qty_2 = int(self.input_Quantity_Set_2.get())
        yield_factor_2 = float(self.input_Yield_Factor_Set_2.get())
        rate_increase_2 = float(self.input_Rate_Increase_Set_2.get())
        leadtime_2 = int(self.input_Lead_Time_Set_2.get())
        duration_2 = int(self.input_Duration_Set_2.get())
        
        self.t_values_1, self.x_values_months_1, self.x_values_years_1 = self.calculate_x_values(duration_1, leadtime_1)
        self.t_values_2, self.x_values_months_2, self.x_values_years_2 = self.calculate_x_values(duration_2, leadtime_2)

        # Plot both charts
        # See Plotting Functions notebook for now. Is it better to do the following: 
        # self.plot_line_chart()
        # self.plot_bubble_chart()
        # Or should I handle these functions outside of the class and use unique parameters instead?


    def create_input_field(self, label_text, input_id, row, column, default_value=""):
        """Helper function to create a label and entry field."""
        label = tk.Label(self, text=label_text)
        label.grid(row=row, column=column, padx=10, pady=5, sticky="e")

        entry = tk.Entry(self)
        entry.insert(0, default_value)  # Insert default value into entry field
        entry.grid(row=row, column=column + 1, padx=10, pady=5, sticky="w")

        setattr(self, input_id, entry)
   

    def clear_frame(self, frame):
        """Clear all widgets from a frame."""
        for widget in frame.winfo_children():
            widget.destroy()
# Plot charts
app = EVM_app()
app.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\CassieLynn\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\CassieLynn\AppData\Local\Temp\ipykernel_27424\3873073186.py", line 70, in plot_charts
#     cost_1 = float(self.input_Cost_Set_1.get())
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\CassieLynn\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 2411, in __getattr__
#     return getattr(self.tk, attr)
#            ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_tkinter.tkapp' object has no attribute 'input_Cost_Set_1'
